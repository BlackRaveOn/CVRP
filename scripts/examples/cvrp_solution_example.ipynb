# %%
from scripts.source.cvrp_solver import AntColonySolver

params =  {
            "alpha": 1,
            "beta": 2,
            "sigma": 3,
            "q": 0.8,
            "theta": 20,
            "iterations": 10000,
            "ants": 4
             }

folder = "/benchmarks/E/"
dataset = "E-n22-k4"

colony = AntColonySolver(**params)
colony.fit(folder, dataset, verbose=500, early_stop=3000)
colony.get_best_solution()
colony.plot_solution_routes()
# Out:
# 0:	563
# 500:	383
# 1000:	383
# 1500:	383
# 2000:	378
# 2500:	378
# 3000:	378
# 3500:	378
# 4000:	378
# 4500:	378
